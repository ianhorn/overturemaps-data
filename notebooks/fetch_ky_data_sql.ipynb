# %%
import duckdb

# %% [markdown]
# ### Add Kentucky Boundary
#
# Add Kentucky Boundary from _kybnd.parquet_ to latest.ddb main tables

# %%
with duckdb.connect('../latest.ddb') as conn:
    conn.sql("""
             INSTALL spatial;
             LOAD spatial;

             CREATE OR REPLACE TABLE ky_bnd AS
             SELECT * 
             FROM read_parquet('../parquets/kybnd.parquet')
             """)
    
    print('Table ky_bnd created.')
# Out:
# Table ky_bnd created.

# %% [markdown]
# ### Kentucky Extent
#
# calculated min/max from state boundary ky_bnd table.
# `-89.57122, 36.49706, -81.96479, 39.14774`
#
# bbox sql:
#
# ```sql
#     bbox.xmin BETWEEN -89.57122 AND -81.96479
#     AND bbox.ymin BETWEEN 36.49706 AND 39.14774
# ```

# %%
# Tables where Kentucky can be queried from the table
# eliminating the need to run a spatial query on Ky's 
# border geometry.
# bbox will be used to narrow down the field of view.


with duckdb.connect('../latest.ddb') as conn:
  conn.sql("""
  LOAD spatial;
  
  CREATE OR REPLACE TABLE place as
  WITH kybbox as (
        SELECT * FROM place_vw
        WHERE bbox.xmin BETWEEN -89.57122 AND -81.96479
          AND bbox.ymin BETWEEN 36.49706 AND 39.14774
        )
        SELECT * from kybbox,  
          UNNEST(kybbox.addresses) as a                    
        WHERE a.unnest.region = 'KY'
  """)

  print('Table place created.\n')
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[4], line 22
#       7 with duckdb.connect('latest.ddb') as conn:
#       8   conn.sql("""
#       9   LOAD spatial;
#      10
#    (...)
#      19         WHERE a.unnest.region = 'KY'
#      20   """)
# ---> 22   print('Table place created.\n')
#
# Cell In[4], line 8
#       1 # Tables where Kentucky can be queried from the table
#       2 # eliminating the need to run a spatial query on Ky's
#       3 # border geometry.
#       4 # bbox will be used to narrow down the field of view.
#       7 with duckdb.connect('latest.ddb') as conn:
# ----> 8   conn.sql("""
#       9   LOAD spatial;
#      10
#      11   CREATE OR REPLACE TABLE place as
#      12   WITH kybbox as (
#      13         SELECT * FROM place_vw
#      14         WHERE bbox.xmin BETWEEN -89.57122 AND -81.96479
#      15           AND bbox.ymin BETWEEN 36.49706 AND 39.14774
#      16         )
#      17         SELECT * from kybbox,
#      18           UNNEST(kybbox.addresses) as a
#      19         WHERE a.unnest.region = 'KY'
#      20   """)
#      22   print('Table place created.\n')
#
# CatalogException: Catalog Error: Table with name place_vw does not exist!
# Did you mean "pg_views"?
#
# LINE 6:         WHERE bbox.xmin BETWEEN -89.57122 AND -81.96479
#                ^

# %% [markdown]
# ### Clip to Kentucky Border
#
# These tables will need further processsing.
#
#  - Step 1: query to bounding box
#  - Step2:  clip to Kentucky boundary

# %%
with duckdb.connect('latest.ddb') as conn:
    conn.sql("""
        LOAD spatial;
        CREATE OR REPLACE TABLE infrastructure AS
        SELECT * 
        FROM infrastructure_vw
        WHERE bbox.xmin BETWEEN -89.57122 AND -81.96479
            AND bbox.ymin BETWEEN 36.49706 AND 39.14774
""")
